# %% [markdown]
# 1) Importando bibliotecas e exibindo planilhas originais

# %%
import pandas as pd
import numpy as np

# %%
df_janeiro = pd.read_csv('./dados/focos_mensal_br_202401.csv')
df_fevereiro = pd.read_csv('./dados/focos_mensal_br_202402.csv')
df_marco = pd.read_csv('./dados/focos_mensal_br_202403.csv')
df_abril = pd.read_csv('./dados/focos_mensal_br_202404.csv')
df_maio = pd.read_csv('./dados/focos_mensal_br_202405.csv')
df_junho = pd.read_csv('./dados/focos_mensal_br_202406.csv')

# %%
df_janeiro
df_fevereiro
df_marco
df_abril
df_maio
df_junho
# Out:
#                                           id      lat      lon  \
# 0       9a3beb77-47d0-3372-859b-674c3ad12e6e -11.1900 -53.8100
# 1       6060a777-88d5-3ef7-bb08-cc2e9ad8c6db -11.1523 -54.3104
# 2       f6241985-6055-34b5-b198-217e365d77df -11.2151 -53.8125
# 3       d8fa8528-59fb-3017-8acf-6303115633b7 -11.1959 -53.8348
# 4       d2946224-4114-3191-87fb-a78feeb0e6d6 -11.1962 -53.8142
# ...                                      ...      ...      ...
# 353038  feb4f53b-e202-350c-8f74-7f82fc40cb1d -19.6805 -57.0351
# 353039  7fcb2a72-dd94-33e5-b249-69de261a3faf -19.6801 -57.0561
# 353040  7d66733d-24fd-3205-967d-17dc67e60fd2 -20.0190 -42.8786
# 353041  defe4e3a-b07b-30a1-9a9c-9e3403ab2967 -19.6604 -57.0379
# 353042  d15da0b9-9675-311a-b106-234123bb16bb -20.0396 -42.8728
#
#               data_hora_gmt satelite              municipio  \
# 0       2024-06-01 00:04:22   MSG-03            MARCELÂNDIA
# 1       2024-06-01 00:06:07  GOES-16            MARCELÂNDIA
# 2       2024-06-01 00:06:08  GOES-16            MARCELÂNDIA
# 3       2024-06-01 00:06:08  GOES-16            MARCELÂNDIA
# 4       2024-06-01 00:06:08  GOES-16            MARCELÂNDIA
# ...                     ...      ...                    ...
# 353038  2024-06-30 23:36:57  GOES-16                CORUMBÁ
# 353039  2024-06-30 23:36:57  GOES-16                CORUMBÁ
# 353040  2024-06-30 23:36:57  GOES-16  SÃO DOMINGOS DO PRATA
# 353041  2024-06-30 23:36:57  GOES-16                CORUMBÁ
# 353042  2024-06-30 23:36:57  GOES-16              SEM-PEIXE
#
#                     estado    pais  municipio_id  estado_id  pais_id  \
# 0              MATO GROSSO  Brasil       5105580         51       33
# 1              MATO GROSSO  Brasil       5105580         51       33
# 2              MATO GROSSO  Brasil       5105580         51       33
# 3              MATO GROSSO  Brasil       5105580         51       33
# 4              MATO GROSSO  Brasil       5105580         51       33
# ...                    ...     ...           ...        ...      ...
# 353038  MATO GROSSO DO SUL  Brasil       5003207         50       33
# 353039  MATO GROSSO DO SUL  Brasil       5003207         50       33
# 353040        MINAS GERAIS  Brasil       3161007         31       33
# 353041  MATO GROSSO DO SUL  Brasil       5003207         50       33
# 353042        MINAS GERAIS  Brasil       3165560         31       33
#
#         numero_dias_sem_chuva  precipitacao  risco_fogo           bioma    frp
# 0                          34           0.0        0.39        Amazônia    NaN
# 1                          34           0.0        0.36        Amazônia  101.0
# 2                          34           0.0        0.40        Amazônia  358.9
# 3                          34           0.0        0.40        Amazônia   50.5
# 4                          34           0.0        0.40        Amazônia   87.1
# ...                       ...           ...         ...             ...    ...
# 353038                     62           0.0        0.84        Pantanal  106.4
# 353039                     60           0.0        0.94        Pantanal   60.7
# 353040                     88           0.0        1.00  Mata Atlântica   86.7
# 353041                     60           0.0        0.89        Pantanal   68.3
# 353042                     88           0.0        0.99  Mata Atlântica   65.0
#
# [353043 rows x 16 columns]

# %% [markdown]
# 2) Concatenando as planilhas

# %%
#setando o caminho + arquivos que serão concatenados
path = 'dados/focos_mensal_br_2024'

#concatenar os arquivos csv com o nome igual ao setado em "path"
df_brasil_2024 = pd.concat([pd.read_csv(f"{path}{mes:02}.csv") for mes in range(1,7)])

#exibir a tabela concatenada
df_brasil_2024
# Out:
#                                           id      lat      lon  \
# 0       966ed445-fa70-3369-9802-3e74c5765684 -12.5667 -41.4364
# 1       0669c14d-7a39-3d98-9f20-23e118fbcf09 -12.5662 -41.4611
# 2       53a46800-fa40-3323-9b20-05108d435c24 -18.0629 -57.3721
# 3       d0af560b-c440-3554-a5c6-83fb055304e8 -18.0823 -57.3902
# 4       b509b339-729d-3a30-a7d9-8a6a33398a4f -18.0823 -57.3902
# ...                                      ...      ...      ...
# 353038  feb4f53b-e202-350c-8f74-7f82fc40cb1d -19.6805 -57.0351
# 353039  7fcb2a72-dd94-33e5-b249-69de261a3faf -19.6801 -57.0561
# 353040  7d66733d-24fd-3205-967d-17dc67e60fd2 -20.0190 -42.8786
# 353041  defe4e3a-b07b-30a1-9a9c-9e3403ab2967 -19.6604 -57.0379
# 353042  d15da0b9-9675-311a-b106-234123bb16bb -20.0396 -42.8728
#
#               data_hora_gmt satelite              municipio  \
# 0       2024-01-01 00:06:16  GOES-16                LENÇÓIS
# 1       2024-01-01 00:06:16  GOES-16                LENÇÓIS
# 2       2024-01-01 00:06:48  GOES-16                CORUMBÁ
# 3       2024-01-01 00:06:48  GOES-16                CORUMBÁ
# 4       2024-01-01 00:16:48  GOES-16                CORUMBÁ
# ...                     ...      ...                    ...
# 353038  2024-06-30 23:36:57  GOES-16                CORUMBÁ
# 353039  2024-06-30 23:36:57  GOES-16                CORUMBÁ
# 353040  2024-06-30 23:36:57  GOES-16  SÃO DOMINGOS DO PRATA
# 353041  2024-06-30 23:36:57  GOES-16                CORUMBÁ
# 353042  2024-06-30 23:36:57  GOES-16              SEM-PEIXE
#
#                     estado    pais  municipio_id  estado_id  pais_id  \
# 0                    BAHIA  Brasil       2919306         29       33
# 1                    BAHIA  Brasil       2919306         29       33
# 2       MATO GROSSO DO SUL  Brasil       5003207         50       33
# 3       MATO GROSSO DO SUL  Brasil       5003207         50       33
# 4       MATO GROSSO DO SUL  Brasil       5003207         50       33
# ...                    ...     ...           ...        ...      ...
# 353038  MATO GROSSO DO SUL  Brasil       5003207         50       33
# 353039  MATO GROSSO DO SUL  Brasil       5003207         50       33
# 353040        MINAS GERAIS  Brasil       3161007         31       33
# 353041  MATO GROSSO DO SUL  Brasil       5003207         50       33
# 353042        MINAS GERAIS  Brasil       3165560         31       33
#
#         numero_dias_sem_chuva  precipitacao  risco_fogo           bioma    frp
# 0                           8          1.38        0.70        Caatinga   76.5
# 1                           9          1.73        0.83        Caatinga   81.4
# 2                           0         14.42        0.00        Pantanal   59.8
# 3                           0         12.93     -999.00        Pantanal   63.4
# 4                           0         12.93     -999.00        Pantanal   64.6
# ...                       ...           ...         ...             ...    ...
# 353038                     62          0.00        0.84        Pantanal  106.4
# 353039                     60          0.00        0.94        Pantanal   60.7
# 353040                     88          0.00        1.00  Mata Atlântica   86.7
# 353041                     60          0.00        0.89        Pantanal   68.3
# 353042                     88          0.00        0.99  Mata Atlântica   65.0
#
# [983232 rows x 16 columns]

# %%
#mostrar quantidade de celulas x colunas
df_brasil_2024.shape
# Out:
# (983232, 16)

# %%
#descrever 
df_brasil_2024.describe()
# Out:
#                  lat            lon  municipio_id      estado_id   pais_id  \
# count  983232.000000  983232.000000  9.832320e+05  983232.000000  983232.0
# mean       -9.993129     -53.809391  3.189780e+06      31.827838      33.0
# std         8.596091       6.936608  1.611532e+06      16.108001       0.0
# min       -33.715350     -73.666210  1.100015e+06      11.000000      33.0
# 25%       -17.497535     -60.026930  1.400472e+06      14.000000      33.0
# 50%       -11.185035     -56.279550  2.922250e+06      29.000000      33.0
# 75%        -2.304890     -48.093350  5.006903e+06      50.000000      33.0
# max         5.163930     -34.809400  5.300108e+06      53.000000      33.0
#
#        numero_dias_sem_chuva   precipitacao     risco_fogo            frp
# count          983232.000000  983232.000000  983232.000000  951407.000000
# mean                9.495614       0.690434     -21.650540      33.780956
# std               104.052397       3.708917     147.580664      57.590815
# min              -999.000000       0.000000    -999.000000       0.000000
# 25%                 5.000000       0.000000       0.210000       3.800000
# 50%                14.000000       0.000000       0.770000       9.400000
# 75%                29.000000       0.000000       1.000000      54.200000
# max                93.000000     252.980000       1.000000    4720.700000

# %%
#verificando quais colunas possuem valores nulos
df_brasil_2024.isnull().sum()
# Out:
# id                           0
# lat                          0
# lon                          0
# data_hora_gmt                0
# satelite                     0
# municipio                    0
# estado                       0
# pais                         0
# municipio_id                 0
# estado_id                    0
# pais_id                      0
# numero_dias_sem_chuva        0
# precipitacao                 0
# risco_fogo                   0
# bioma                        1
# frp                      31825
# dtype: int64

# %% [markdown]
# 3) Removendo espaços em branco

# %%
#remover espaços em branco dos nomes das colunas

df_brasil_2024.columns = df_brasil_2024.columns.str.strip()

#remover espaços em branco dos dados das células

df_brasil_2024 = df_brasil_2024.apply(lambda x: x.str.strip() if x.dtype == "object" else x)

df_brasil_2024
# Out:
#                                           id      lat      lon  \
# 0       966ed445-fa70-3369-9802-3e74c5765684 -12.5667 -41.4364
# 1       0669c14d-7a39-3d98-9f20-23e118fbcf09 -12.5662 -41.4611
# 2       53a46800-fa40-3323-9b20-05108d435c24 -18.0629 -57.3721
# 3       d0af560b-c440-3554-a5c6-83fb055304e8 -18.0823 -57.3902
# 4       b509b339-729d-3a30-a7d9-8a6a33398a4f -18.0823 -57.3902
# ...                                      ...      ...      ...
# 353038  feb4f53b-e202-350c-8f74-7f82fc40cb1d -19.6805 -57.0351
# 353039  7fcb2a72-dd94-33e5-b249-69de261a3faf -19.6801 -57.0561
# 353040  7d66733d-24fd-3205-967d-17dc67e60fd2 -20.0190 -42.8786
# 353041  defe4e3a-b07b-30a1-9a9c-9e3403ab2967 -19.6604 -57.0379
# 353042  d15da0b9-9675-311a-b106-234123bb16bb -20.0396 -42.8728
#
#               data_hora_gmt satelite              municipio  \
# 0       2024-01-01 00:06:16  GOES-16                LENÇÓIS
# 1       2024-01-01 00:06:16  GOES-16                LENÇÓIS
# 2       2024-01-01 00:06:48  GOES-16                CORUMBÁ
# 3       2024-01-01 00:06:48  GOES-16                CORUMBÁ
# 4       2024-01-01 00:16:48  GOES-16                CORUMBÁ
# ...                     ...      ...                    ...
# 353038  2024-06-30 23:36:57  GOES-16                CORUMBÁ
# 353039  2024-06-30 23:36:57  GOES-16                CORUMBÁ
# 353040  2024-06-30 23:36:57  GOES-16  SÃO DOMINGOS DO PRATA
# 353041  2024-06-30 23:36:57  GOES-16                CORUMBÁ
# 353042  2024-06-30 23:36:57  GOES-16              SEM-PEIXE
#
#                     estado    pais  municipio_id  estado_id  pais_id  \
# 0                    BAHIA  Brasil       2919306         29       33
# 1                    BAHIA  Brasil       2919306         29       33
# 2       MATO GROSSO DO SUL  Brasil       5003207         50       33
# 3       MATO GROSSO DO SUL  Brasil       5003207         50       33
# 4       MATO GROSSO DO SUL  Brasil       5003207         50       33
# ...                    ...     ...           ...        ...      ...
# 353038  MATO GROSSO DO SUL  Brasil       5003207         50       33
# 353039  MATO GROSSO DO SUL  Brasil       5003207         50       33
# 353040        MINAS GERAIS  Brasil       3161007         31       33
# 353041  MATO GROSSO DO SUL  Brasil       5003207         50       33
# 353042        MINAS GERAIS  Brasil       3165560         31       33
#
#         numero_dias_sem_chuva  precipitacao  risco_fogo           bioma    frp
# 0                           8          1.38        0.70        Caatinga   76.5
# 1                           9          1.73        0.83        Caatinga   81.4
# 2                           0         14.42        0.00        Pantanal   59.8
# 3                           0         12.93     -999.00        Pantanal   63.4
# 4                           0         12.93     -999.00        Pantanal   64.6
# ...                       ...           ...         ...             ...    ...
# 353038                     62          0.00        0.84        Pantanal  106.4
# 353039                     60          0.00        0.94        Pantanal   60.7
# 353040                     88          0.00        1.00  Mata Atlântica   86.7
# 353041                     60          0.00        0.89        Pantanal   68.3
# 353042                     88          0.00        0.99  Mata Atlântica   65.0
#
# [983232 rows x 16 columns]

# %% [markdown]
# 4) Removendo colunas indesejadas

# %%
#exibir nome das colunas
df_brasil_2024.columns
# Out:
# Index(['id', 'lat', 'lon', 'data_hora_gmt', 'satelite', 'municipio', 'estado',
#        'pais', 'municipio_id', 'estado_id', 'pais_id', 'numero_dias_sem_chuva',
#        'precipitacao', 'risco_fogo', 'bioma', 'frp'],
#       dtype='object')

# %%
#renomear colunas
df_brasil_2024.rename(columns={'lat': 'latitude', 'lon': 'longitude'}, inplace=True)

# %%
#removendo colunas
df_brasil_2024.drop('frp', axis=1, inplace=True)
df_brasil_2024.drop('id', axis=1, inplace=True)
df_brasil_2024.drop('pais', axis=1, inplace=True)
df_brasil_2024.drop('municipio_id', axis=1, inplace=True)
df_brasil_2024.drop('estado_id', axis=1, inplace=True)
df_brasil_2024.drop('pais_id', axis=1, inplace=True)

# %%
df_brasil_2024
# Out:
#         latitude  longitude        data_hora_gmt satelite  \
# 0       -12.5667   -41.4364  2024-01-01 00:06:16  GOES-16
# 1       -12.5662   -41.4611  2024-01-01 00:06:16  GOES-16
# 2       -18.0629   -57.3721  2024-01-01 00:06:48  GOES-16
# 3       -18.0823   -57.3902  2024-01-01 00:06:48  GOES-16
# 4       -18.0823   -57.3902  2024-01-01 00:16:48  GOES-16
# ...          ...        ...                  ...      ...
# 353038  -19.6805   -57.0351  2024-06-30 23:36:57  GOES-16
# 353039  -19.6801   -57.0561  2024-06-30 23:36:57  GOES-16
# 353040  -20.0190   -42.8786  2024-06-30 23:36:57  GOES-16
# 353041  -19.6604   -57.0379  2024-06-30 23:36:57  GOES-16
# 353042  -20.0396   -42.8728  2024-06-30 23:36:57  GOES-16
#
#                     municipio              estado  numero_dias_sem_chuva  \
# 0                     LENÇÓIS               BAHIA                      8
# 1                     LENÇÓIS               BAHIA                      9
# 2                     CORUMBÁ  MATO GROSSO DO SUL                      0
# 3                     CORUMBÁ  MATO GROSSO DO SUL                      0
# 4                     CORUMBÁ  MATO GROSSO DO SUL                      0
# ...                       ...                 ...                    ...
# 353038                CORUMBÁ  MATO GROSSO DO SUL                     62
# 353039                CORUMBÁ  MATO GROSSO DO SUL                     60
# 353040  SÃO DOMINGOS DO PRATA        MINAS GERAIS                     88
# 353041                CORUMBÁ  MATO GROSSO DO SUL                     60
# 353042              SEM-PEIXE        MINAS GERAIS                     88
#
#         precipitacao  risco_fogo           bioma
# 0               1.38        0.70        Caatinga
# 1               1.73        0.83        Caatinga
# 2              14.42        0.00        Pantanal
# 3              12.93     -999.00        Pantanal
# 4              12.93     -999.00        Pantanal
# ...              ...         ...             ...
# 353038          0.00        0.84        Pantanal
# 353039          0.00        0.94        Pantanal
# 353040          0.00        1.00  Mata Atlântica
# 353041          0.00        0.89        Pantanal
# 353042          0.00        0.99  Mata Atlântica
#
# [983232 rows x 10 columns]
